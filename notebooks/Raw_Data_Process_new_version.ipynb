# %%
import pandas as pd
import numpy as np
import re,os,json,pprint
import datetime
import emoji
import csv

# %%
def check_empty_and_unexist_files(file_path_list):
    good_file_path_list = []
    bad_file_path_list = []
    for file_path in file_path_list:
        if os.path.isfile(file_path) and (os.stat(file_path).st_size > 0):
            good_file_path_list.append(file_path)
        else:
            bad_file_path_list.append(file_path)
    if len(bad_file_path_list):
        print('These files are either empty or non-exist: ', bad_file_path_list)
    return good_file_path_list


def load_tweets_from_json(file_path):
    tweets = []
    for line in open(file_path,'r'):
        tweets.append(json.loads(line))
    return tweets


def get_value_by_two_steps(tweet,keys,targets,text):
    original_tweet_text = tweet['text']
    try:
        for key in keys:
            tweet = tweet[key]
    except KeyError:
        return None, text
    if len(tweet):
        if isinstance(targets,str):
            targets = (targets,)
        result = []
        for single_item in tweet:
            single_value = tuple((single_item[temp_target] for temp_target in targets))
            if len(single_value) == 1:
                single_value = single_value[0]
            result.append(single_value)
            #remove targets
            indices = single_item['indices']
            target_string = original_tweet_text[indices[0]:indices[1]]
            text = text.replace(target_string,'')
        if len(result) == 1:
            result = result[0]
        return result,text
    else:
        return None,text
    
def extract_emojis(txt):
    return ''.join(c for c in txt if c in emoji.UNICODE_EMOJI)

def extract_no_emojis_text(txt):
    txt =  ''.join(c for c in txt if c not in emoji.UNICODE_EMOJI)
    return ' '.join(word for word in txt.split() if '@' not in word)

# %%
dirPath = '../data/state_id_2014-06_unzip/'
file_name_list = os.listdir(dirPath)
file_name_list = [file_name for file_name in file_name_list if re.findall('.+\.json$',file_name)]
file_path_list = [dirPath + file_name for file_name in file_name_list]

file_path_list = check_empty_and_unexist_files(file_path_list)

# %%
header = ['Tweet ID', 'timestamp', 'week', 'user_id', 'state', 'original text', 'with_emoji_text', 'without_emoji_text','in_reply_to_status_id_str',  'emoji',
          'hashtag', 'media(type, url)', 'user_mentions', 'language']
final_result = []
fp = open("output.csv", "a") 
wr = csv.writer(fp, dialect='excel')

for file_path in file_path_list:
    state_id = file_path.split('/')[-1].split('_')[1]
    tweets = load_tweets_from_json(file_path)
    i = 0
    for tweet in tweets:
        text = tweet['text']
        print('---------------------------------------------------------')
        print('original text:',text)
        print('emojies: ',extract_emojis(text))
        tweet_id = tweet['id_str']
        user_id = tweet['user']['id']
        language = tweet['lang']
        timestamp = datetime.datetime.strptime(tweet['created_at'],'%a %b %d %H:%M:%S +0000 %Y').timestamp()
        in_reply_to_status_id_str = tweet.get('in_reply_to_status_id_str',None)
        week = datetime.datetime.strptime(tweet['created_at'],'%a %b %d %H:%M:%S +0000 %Y').strftime('%A')
        hashtags,text = get_value_by_two_steps(tweet,['entities','hashtags'],'text',text)
        media,text = get_value_by_two_steps(tweet,['entities','media'],('type','media_url_https'),text)
        symbols,text = get_value_by_two_steps(tweet,['entities','symbols'],'text',text)
        urls,text = get_value_by_two_steps(tweet,['entities','urls'],'url',text)
        user_mentions, text = get_value_by_two_steps(tweet,['entities','user_mentions'],'id_str',text)
        text = re.sub( '\s+', ' ', text ).strip()
        print('\nhashtags: ',hashtags,'\nmedia: ',media,'\nsymbols: ',symbols,
              '\nurls: ',urls,'\nuser_mentions: ',user_mentions)
        print('\n with emoji',text)
        print('\n without emoji',extract_no_emojis_text(text))
        list_a_data = ([tweet_id, timestamp, week, user_id, state_id, tweet['text'], text, extract_no_emojis_text(text),in_reply_to_status_id_str,extract_emojis(text),
                            hashtags, media, user_mentions, language])
        wr.writerow(list_a_data)
        i = i +1
        if i > 100:
            break
        
    break
# Out:
# ---------------------------------------------------------
# original text: I just made a fabulous grilled cheese omg 😍
# emojies:  😍
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji I just made a fabulous grilled cheese omg 😍
#
#  without emoji I just made a fabulous grilled cheese omg
# ---------------------------------------------------------
# original text: "What the frick" - @ash_morrison12
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  1102590956
#
#  with emoji "What the frick" -
#
#  without emoji "What the frick" -
# ---------------------------------------------------------
# original text: @paigeschwarzroc comin
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  1871717250
#
#  with emoji comin
#
#  without emoji comin
# ---------------------------------------------------------
# original text: Glora-"Bryannnnnnn"
# Me-"Wuuuuuuuut"
# Gloria-"Youre gonna make me ugly cry"
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Glora-"Bryannnnnnn" Me-"Wuuuuuuuut" Gloria-"Youre gonna make me ugly cry"
#
#  without emoji Glora-"Bryannnnnnn" Me-"Wuuuuuuuut" Gloria-"Youre gonna make me ugly cry"
# ---------------------------------------------------------
# original text: I just want my big brother to come home ):
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji I just want my big brother to come home ):
#
#  without emoji I just want my big brother to come home ):
# ---------------------------------------------------------
# original text: Naked? 😍
# emojies:  😍
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Naked? 😍
#
#  without emoji Naked?
# ---------------------------------------------------------
# original text: Lol workin (@ Brainerd Dispatch) http://t.co/aZnNtwmG1x
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  http://t.co/aZnNtwmG1x
# user_mentions:  None
#
#  with emoji Lol workin (@ Brainerd Dispatch)
#
#  without emoji Lol workin Brainerd Dispatch)
# ---------------------------------------------------------
# original text: “@FunnyVines: Blarghablabla.. https://t.co/fxVtT9CaB1”@AnnaGiebink  this is us
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  https://t.co/fxVtT9CaB1
# user_mentions:  ['1396161031', '1234948957']
#
#  with emoji “: Blarghablabla.. ” this is us
#
#  without emoji “: Blarghablabla.. ” this is us
# ---------------------------------------------------------
# original text: @CallMeKarizma Then we're all dead
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  461676724
#
#  with emoji Then we're all dead
#
#  without emoji Then we're all dead
# ---------------------------------------------------------
# original text: @4orelllaaaa @LilMont_ nigga look like a Wendy's chicken nugget yo fat ass
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  ['39367535', '729907855940157440']
#
#  with emoji nigga look like a Wendy's chicken nugget yo fat ass
#
#  without emoji nigga look like a Wendy's chicken nugget yo fat ass
# ---------------------------------------------------------
# original text: @JackStamman @babylohnerr mooning people but that's not like an insult to us..
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  ['299418400', '444135301']
#
#  with emoji mooning people but that's not like an insult to us..
#
#  without emoji mooning people but that's not like an insult to us..
# ---------------------------------------------------------
# original text: I wish I had some steak.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji I wish I had some steak.
#
#  without emoji I wish I had some steak.
# ---------------------------------------------------------
# original text: Im a down to earth guy with intentions that’s right.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Im a down to earth guy with intentions that’s right.
#
#  without emoji Im a down to earth guy with intentions that’s right.
# ---------------------------------------------------------
# original text: Furthest thing from perfect like everyone I know 💯
# emojies:  💯
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Furthest thing from perfect like everyone I know 💯
#
#  without emoji Furthest thing from perfect like everyone I know
# ---------------------------------------------------------
# original text: @laneyj42 @_Breezy_10 hey
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  ['324183865', '497563855']
#
#  with emoji hey
#
#  without emoji hey
# ---------------------------------------------------------
# original text: "@althepaaal: Can't I just have a male friend who isn't always trying to be more..."
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  1375322414
#
#  with emoji ": Can't I just have a male friend who isn't always trying to be more..."
#
#  without emoji ": Can't I just have a male friend who isn't always trying to be more..."
# ---------------------------------------------------------
# original text: @NeenoBrowne you guess pshhhhhh lol
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji @NeenoBrowne you guess pshhhhhh lol
#
#  without emoji you guess pshhhhhh lol
# ---------------------------------------------------------
# original text: happy birthday to my closest to a brother. love you @218Tate http://t.co/WQddTV2XGc
# emojies:
#
# hashtags:  None
# media:  ('photo', 'https://pbs.twimg.com/media/Bq36w1uCcAErJt6.jpg')
# symbols:  None
# urls:  None
# user_mentions:  91880592
#
#  with emoji happy birthday to my closest to a brother. love you
#
#  without emoji happy birthday to my closest to a brother. love you
# ---------------------------------------------------------
# original text: @Lo_vanelsen thanks
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji @Lo_vanelsen thanks
#
#  without emoji thanks
# ---------------------------------------------------------
# original text: I drank more than a pitcher of diet coke in an hour so I might explode
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji I drank more than a pitcher of diet coke in an hour so I might explode
#
#  without emoji I drank more than a pitcher of diet coke in an hour so I might explode
# ---------------------------------------------------------
# original text: @ledonneforte @MrPrez35 @TheNoorFacee BETTT
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  427774568
#
#  with emoji @ledonneforte @TheNoorFacee BETTT
#
#  without emoji BETTT
# ---------------------------------------------------------
# original text: @i_G0T_Clout 😂😂 oh yeah llmao that was dem good ol days
# emojies:  😂😂
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  900112582555598852
#
#  with emoji 😂😂 oh yeah llmao that was dem good ol days
#
#  without emoji oh yeah llmao that was dem good ol days
# ---------------------------------------------------------
# original text: I wish I had a cute boy who sent me cute little good morning texts and cute goodnight texts and you know just really cute texts.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji I wish I had a cute boy who sent me cute little good morning texts and cute goodnight texts and you know just really cute texts.
#
#  without emoji I wish I had a cute boy who sent me cute little good morning texts and cute goodnight texts and you know just really cute texts.
# ---------------------------------------------------------
# original text: I never go on twitter
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji I never go on twitter
#
#  without emoji I never go on twitter
# ---------------------------------------------------------
# original text: “@PraiseTheGanja: Imma kill this nigga 💯💯 http://t.co/iqGmtzTQai”who tf took the picture..
# emojies:  💯💯
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  http://t.co/iqGmtzTQai
# user_mentions:  None
#
#  with emoji “@PraiseTheGanja: Imma kill this nigga 💯💯 ”who tf took the picture..
#
#  without emoji Imma kill this nigga ”who tf took the picture..
# ---------------------------------------------------------
# original text: @JackStamman @babylohnerr what is that suppose to mean?
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  ['299418400', '444135301']
#
#  with emoji what is that suppose to mean?
#
#  without emoji what is that suppose to mean?
# ---------------------------------------------------------
# original text: Getting mixed signals is the worst!
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Getting mixed signals is the worst!
#
#  without emoji Getting mixed signals is the worst!
# ---------------------------------------------------------
# original text: How's it going baby 😏
# emojies:  😏
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji How's it going baby 😏
#
#  without emoji How's it going baby
# ---------------------------------------------------------
# original text: My phone fucking acts up when it's on the charger 😒
# emojies:  😒
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji My phone fucking acts up when it's on the charger 😒
#
#  without emoji My phone fucking acts up when it's on the charger
# ---------------------------------------------------------
# original text: @MyBlueWorld777 G'night sweets xo:)
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  329893254
#
#  with emoji G'night sweets xo:)
#
#  without emoji G'night sweets xo:)
# ---------------------------------------------------------
# original text: The amount of Stevie Wonder that's in my head right now is unhealthy.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji The amount of Stevie Wonder that's in my head right now is unhealthy.
#
#  without emoji The amount of Stevie Wonder that's in my head right now is unhealthy.
# ---------------------------------------------------------
# original text: You honestly make me feel so stupid
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji You honestly make me feel so stupid
#
#  without emoji You honestly make me feel so stupid
# ---------------------------------------------------------
# original text: My bro bout to get signed watch @Eye2i_
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji My bro bout to get signed watch @Eye2i_
#
#  without emoji My bro bout to get signed watch
# ---------------------------------------------------------
# original text: @studioloraine c'mon friday!..but go easy :)
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  6430402
#
#  with emoji c'mon friday!..but go easy :)
#
#  without emoji c'mon friday!..but go easy :)
# ---------------------------------------------------------
# original text: Courntey music is the death of me
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Courntey music is the death of me
#
#  without emoji Courntey music is the death of me
# ---------------------------------------------------------
# original text: Only my mother would make me clean my room right now
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Only my mother would make me clean my room right now
#
#  without emoji Only my mother would make me clean my room right now
# ---------------------------------------------------------
# original text: What you do speaks so loud that I cannot hear what you say. - Ralph Waldo Emerson
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji What you do speaks so loud that I cannot hear what you say. - Ralph Waldo Emerson
#
#  without emoji What you do speaks so loud that I cannot hear what you say. - Ralph Waldo Emerson
# ---------------------------------------------------------
# original text: @TheJokeIsMe no idea.. just do
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  3354866446
#
#  with emoji no idea.. just do
#
#  without emoji no idea.. just do
# ---------------------------------------------------------
# original text: "@JonnyCutsStuff: The sky is amazing tonight." seriously is! !!!!
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji "@JonnyCutsStuff: The sky is amazing tonight." seriously is! !!!!
#
#  without emoji The sky is amazing tonight." seriously is! !!!!
# ---------------------------------------------------------
# original text: @i_G0T_Clout nigga lil B u sound dumb
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  900112582555598852
#
#  with emoji nigga lil B u sound dumb
#
#  without emoji nigga lil B u sound dumb
# ---------------------------------------------------------
# original text: I can't wait to start a new chapter in my life, but yet.. I don't want to leave the people I have in this chapter. 😊😔 http://t.co/cOL5CIDvJy
# emojies:  😊😔
#
# hashtags:  None
# media:  ('photo', 'https://pbs.twimg.com/media/Bq36qivCcAAq4fK.jpg')
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji I can't wait to start a new chapter in my life, but yet.. I don't want to leave the people I have in this chapter. 😊😔
#
#  without emoji I can't wait to start a new chapter in my life, but yet.. I don't want to leave the people I have in this chapter.
# ---------------------------------------------------------
# original text: I can't believe Isabelle just texted me ❤️ I'm crying so much, my baby is safe, oh my gosh I'm thankful, God am I thankful
# emojies:  ❤
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji I can't believe Isabelle just texted me ❤️ I'm crying so much, my baby is safe, oh my gosh I'm thankful, God am I thankful
#
#  without emoji I can't believe Isabelle just texted me ️ I'm crying so much, my baby is safe, oh my gosh I'm thankful, God am I thankful
# ---------------------------------------------------------
# original text: If you truly love someone, being faithful is easy.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji If you truly love someone, being faithful is easy.
#
#  without emoji If you truly love someone, being faithful is easy.
# ---------------------------------------------------------
# original text: @skleina30 excuse me, did u leave me any?
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  260491860
#
#  with emoji excuse me, did u leave me any?
#
#  without emoji excuse me, did u leave me any?
# ---------------------------------------------------------
# original text: @KingFuvi past ouch!!!
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  383352208
#
#  with emoji past ouch!!!
#
#  without emoji past ouch!!!
# ---------------------------------------------------------
# original text: Nu Metal Legend Of Zelda:Linkin Park #RuinAVideoGameCharacter
# emojies:
#
# hashtags:  RuinAVideoGameCharacter
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Nu Metal Legend Of Zelda:Linkin Park
#
#  without emoji Nu Metal Legend Of Zelda:Linkin Park
# ---------------------------------------------------------
# original text: Super Mario's Mafia #RuinAVideoGameCharacter
# emojies:
#
# hashtags:  RuinAVideoGameCharacter
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Super Mario's Mafia
#
#  without emoji Super Mario's Mafia
# ---------------------------------------------------------
# original text: Wind 0.0 mph ---. Barometer 29.823 in, Rising slowly. Temperature 60.0 °F. Rain today 0.00 in. Humidity 88%
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Wind 0.0 mph ---. Barometer 29.823 in, Rising slowly. Temperature 60.0 °F. Rain today 0.00 in. Humidity 88%
#
#  without emoji Wind 0.0 mph ---. Barometer 29.823 in, Rising slowly. Temperature 60.0 °F. Rain today 0.00 in. Humidity 88%
# ---------------------------------------------------------
# original text: @mayaa_marieee good. Go light up a blunt and smoke it for me.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  354132475
#
#  with emoji good. Go light up a blunt and smoke it for me.
#
#  without emoji good. Go light up a blunt and smoke it for me.
# ---------------------------------------------------------
# original text: Only 17 yet she walks the streets so mean.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Only 17 yet she walks the streets so mean.
#
#  without emoji Only 17 yet she walks the streets so mean.
# ---------------------------------------------------------
# original text: Today something amazing happened. Lol actually yesterday cause it's 1:00.. But yeah.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Today something amazing happened. Lol actually yesterday cause it's 1:00.. But yeah.
#
#  without emoji Today something amazing happened. Lol actually yesterday cause it's 1:00.. But yeah.
# ---------------------------------------------------------
# original text: I'm on that with anybody on my twitter feed lol nobody is safe
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji I'm on that with anybody on my twitter feed lol nobody is safe
#
#  without emoji I'm on that with anybody on my twitter feed lol nobody is safe
# ---------------------------------------------------------
# original text: @paigeschwarzroc I lied I'm in bed
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  1871717250
#
#  with emoji I lied I'm in bed
#
#  without emoji I lied I'm in bed
# ---------------------------------------------------------
# original text: ur so cute A ..
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji ur so cute A ..
#
#  without emoji ur so cute A ..
# ---------------------------------------------------------
# original text: :) old http://t.co/b6YSxyQr6l
# emojies:
#
# hashtags:  None
# media:  ('photo', 'https://pbs.twimg.com/media/Bq366GNIYAAHT4y.jpg')
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji :) old
#
#  without emoji :) old
# ---------------------------------------------------------
# original text: So happy I pierced my tongue 😝
# emojies:  😝
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji So happy I pierced my tongue 😝
#
#  without emoji So happy I pierced my tongue
# ---------------------------------------------------------
# original text: I don't know what to say or how to feel.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji I don't know what to say or how to feel.
#
#  without emoji I don't know what to say or how to feel.
# ---------------------------------------------------------
# original text: tropical fusion birthday blizzunt, awe yeah.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji tropical fusion birthday blizzunt, awe yeah.
#
#  without emoji tropical fusion birthday blizzunt, awe yeah.
# ---------------------------------------------------------
# original text: Is it legal to buy a giraffe?? http://t.co/ZN2KfsxezT
# emojies:
#
# hashtags:  None
# media:  ('photo', 'https://pbs.twimg.com/media/Bq37ImzCcAAUZ0b.jpg')
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Is it legal to buy a giraffe??
#
#  without emoji Is it legal to buy a giraffe??
# ---------------------------------------------------------
# original text: @babyvday text me
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  854122302
#
#  with emoji text me
#
#  without emoji text me
# ---------------------------------------------------------
# original text: I think before I make any moves.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji I think before I make any moves.
#
#  without emoji I think before I make any moves.
# ---------------------------------------------------------
# original text: @Gee_Cano  fifita?
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  236552282
#
#  with emoji fifita?
#
#  without emoji fifita?
# ---------------------------------------------------------
# original text: I thank God everyday for the friends I chose to be in my life tho things are not always smooth. Not many are fortunate and can say the same.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji I thank God everyday for the friends I chose to be in my life tho things are not always smooth. Not many are fortunate and can say the same.
#
#  without emoji I thank God everyday for the friends I chose to be in my life tho things are not always smooth. Not many are fortunate and can say the same.
# ---------------------------------------------------------
# original text: Bangers on the way. Bout to show St Paul some real shit
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Bangers on the way. Bout to show St Paul some real shit
#
#  without emoji Bangers on the way. Bout to show St Paul some real shit
# ---------------------------------------------------------
# original text: Be with someone who makes your life better.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Be with someone who makes your life better.
#
#  without emoji Be with someone who makes your life better.
# ---------------------------------------------------------
# original text: Happy birthday @CJaneksela :)))
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  724608542
#
#  with emoji Happy birthday :)))
#
#  without emoji Happy birthday :)))
# ---------------------------------------------------------
# original text: When my hips fall asleep &gt;&gt;&gt;&gt;
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji When my hips fall asleep &gt;&gt;&gt;&gt;
#
#  without emoji When my hips fall asleep &gt;&gt;&gt;&gt;
# ---------------------------------------------------------
# original text: I really don't know how to feel.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji I really don't know how to feel.
#
#  without emoji I really don't know how to feel.
# ---------------------------------------------------------
# original text: "@abrril_: I've already had my heart broken and I  don't think I'll ever give someone the power to hurt me again."
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  298177959
#
#  with emoji ": I've already had my heart broken and I don't think I'll ever give someone the power to hurt me again."
#
#  without emoji ": I've already had my heart broken and I don't think I'll ever give someone the power to hurt me again."
# ---------------------------------------------------------
# original text: I'm in love with the idea of something that doesn't exist
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji I'm in love with the idea of something that doesn't exist
#
#  without emoji I'm in love with the idea of something that doesn't exist
# ---------------------------------------------------------
# original text: I'm with Minnesota for the World Cup. #HelpUsLord #WorldCup2014
# emojies:
#
# hashtags:  ['HelpUsLord', 'WorldCup2014']
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji I'm with Minnesota for the World Cup.
#
#  without emoji I'm with Minnesota for the World Cup.
# ---------------------------------------------------------
# original text: Pull out a AK and pop you in ya funny bone
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Pull out a AK and pop you in ya funny bone
#
#  without emoji Pull out a AK and pop you in ya funny bone
# ---------------------------------------------------------
# original text: Well now im not gona be able to sleep😤
# emojies:  😤
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Well now im not gona be able to sleep😤
#
#  without emoji Well now im not gona be able to sleep
# ---------------------------------------------------------
# original text: @mayaa_marieee damn I should of been messing with you
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  354132475
#
#  with emoji damn I should of been messing with you
#
#  without emoji damn I should of been messing with you
# ---------------------------------------------------------
# original text: Someone bring me food
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Someone bring me food
#
#  without emoji Someone bring me food
# ---------------------------------------------------------
# original text: @FuckM0untain it would be a lot of work. That's the problem.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji @FuckM0untain it would be a lot of work. That's the problem.
#
#  without emoji it would be a lot of work. That's the problem.
# ---------------------------------------------------------
# original text: "@Derpey: when a skinny girl calls herself fat http://t.co/Rx58hgs5fM" @MariDeLaCruz_ This is what I think about @ArndtDanielle
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  http://t.co/Rx58hgs5fM
# user_mentions:  ['598919816', '489044944']
#
#  with emoji ": when a skinny girl calls herself fat " This is what I think about @ArndtDanielle
#
#  without emoji ": when a skinny girl calls herself fat " This is what I think about
# ---------------------------------------------------------
# original text: LLPD are camped out on county J, #WatchOutKiddos ✋👮🚨🚔🚓
# emojies:  ✋👮🚨🚔🚓
#
# hashtags:  WatchOutKiddos
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji LLPD are camped out on county J, ✋👮🚨🚔🚓
#
#  without emoji LLPD are camped out on county J,
# ---------------------------------------------------------
# original text: My hair is about to naturally start dreading itself
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji My hair is about to naturally start dreading itself
#
#  without emoji My hair is about to naturally start dreading itself
# ---------------------------------------------------------
# original text: My gramma has been heavy on my mind. The closer it got to today, she's been gone for a full year.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji My gramma has been heavy on my mind. The closer it got to today, she's been gone for a full year.
#
#  without emoji My gramma has been heavy on my mind. The closer it got to today, she's been gone for a full year.
# ---------------------------------------------------------
# original text: I'm pretty sure that is Josh Bloje up there, #wheelin @chubbzMANboje http://t.co/92RHumJzEf
# emojies:
#
# hashtags:  wheelin
# media:  ('photo', 'https://pbs.twimg.com/media/Bq37spaCEAEtCk4.jpg')
# symbols:  None
# urls:  None
# user_mentions:  194395336
#
#  with emoji I'm pretty sure that is Josh Bloje up there,
#
#  without emoji I'm pretty sure that is Josh Bloje up there,
# ---------------------------------------------------------
# original text: @Jarmuzekk @FuckM0untain id be a cool Asian blonde right..??
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  536963329
#
#  with emoji @FuckM0untain id be a cool Asian blonde right..??
#  without emoji id be a cool Asian blonde right..??
# ---------------------------------------------------------
# original text: When bae lookin fine http://t.co/EKkY6Gli5o
# emojies:
#
# hashtags:  None
# media:  ('photo', 'https://pbs.twimg.com/media/Bq37qO5CUAAKQk2.jpg')
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji When bae lookin fine
#
#  without emoji When bae lookin fine
# ---------------------------------------------------------
# original text: So that's Armenian? #Sideways
# emojies:
#
# hashtags:  Sideways
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji So that's Armenian?
#
#  without emoji So that's Armenian?
# ---------------------------------------------------------
# original text: I miss @derekklejeski
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  1428991230
#
#  with emoji I miss
#
#  without emoji I miss
# ---------------------------------------------------------
# original text: I just really want steak and potatoes right now.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji I just really want steak and potatoes right now.
#
#  without emoji I just really want steak and potatoes right now.
# ---------------------------------------------------------
# original text: @LilMont_ @4orelllaaaa lol bet
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  ['729907855940157440', '39367535']
#
#  with emoji lol bet
#
#  without emoji lol bet
# ---------------------------------------------------------
# original text: Damn it Jimmy Johns why can't you be open 24/7 😫
# emojies:  😫
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Damn it Jimmy Johns why can't you be open 24/7 😫
#
#  without emoji Damn it Jimmy Johns why can't you be open 24/7
# ---------------------------------------------------------
# original text: @Maynizzles dm me your # we going to kick it soon 👌👌
# emojies:  👌👌
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  576590935
#
#  with emoji dm me your # we going to kick it soon 👌👌
#
#  without emoji dm me your # we going to kick it soon
# ---------------------------------------------------------
# original text: @althepaaal sorry I forgot to @ you
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  1375322414
#
#  with emoji sorry I forgot to @ you
#
#  without emoji sorry I forgot to you
# ---------------------------------------------------------
# original text: @aijaisamazing 🌚😏
# emojies:  🌚😏
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji @aijaisamazing 🌚😏
#
#  without emoji
# ---------------------------------------------------------
# original text: Kill your haters with kindness.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Kill your haters with kindness.
#
#  without emoji Kill your haters with kindness.
# ---------------------------------------------------------
# original text: Boondocks to end the night. 👌
# emojies:  👌
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Boondocks to end the night. 👌
#
#  without emoji Boondocks to end the night.
# ---------------------------------------------------------
# original text: Do you ever feel like too much has changed with someone? Like that bond can never be what it was?
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Do you ever feel like too much has changed with someone? Like that bond can never be what it was?
#
#  without emoji Do you ever feel like too much has changed with someone? Like that bond can never be what it was?
# ---------------------------------------------------------
# original text: @JackStamman @babylohnerr still don't see what you're trying to do here...
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  ['299418400', '444135301']
#
#  with emoji still don't see what you're trying to do here...
#
#  without emoji still don't see what you're trying to do here...
# ---------------------------------------------------------
# original text: “@radkld: i like to hangout with people that make me forget to look at my phone” 👏
# emojies:  👏
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji “@radkld: i like to hangout with people that make me forget to look at my phone” 👏
#
#  without emoji i like to hangout with people that make me forget to look at my phone”
# ---------------------------------------------------------
# original text: @mayaa_marieee smh.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  354132475
#
#  with emoji smh.
#
#  without emoji smh.
# ---------------------------------------------------------
# original text: @SnakeFisher007 it shows.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  185374806
#
#  with emoji it shows.
#
#  without emoji it shows.
# ---------------------------------------------------------
# original text: @i_G0T_Clout boy I'm Finna flame yo dirty ear ass getcha it's a juicy contradiction ol starburst head ass
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  900112582555598852
#
#  with emoji boy I'm Finna flame yo dirty ear ass getcha it's a juicy contradiction ol starburst head ass
#
#  without emoji boy I'm Finna flame yo dirty ear ass getcha it's a juicy contradiction ol starburst head ass
# ---------------------------------------------------------
# original text: I'm not very good at calculating shipping costs and basically end up giving my stuff away on @eBay , which defeats the purpose.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  19709040
#
#  with emoji I'm not very good at calculating shipping costs and basically end up giving my stuff away on , which defeats the purpose.
#
#  without emoji I'm not very good at calculating shipping costs and basically end up giving my stuff away on , which defeats the purpose.
# ---------------------------------------------------------
# original text: At 01:01 AM – Temp: 66.9ºF
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji At 01:01 AM – Temp: 66.9ºF
#
#  without emoji At 01:01 AM – Temp: 66.9ºF

# %%
pd.DataFrame(final_result,columns = header)
# Out:
#                Tweet ID     timestamp     week     user_id state  \
# 0    481316532782247938  1.403604e+09  Tuesday    83000504    27
# 1    481315959127293952  1.403604e+09  Tuesday   175445210    27
# 2    481316674315251712  1.403604e+09  Tuesday  1506708626    27
# 3    481315955700547585  1.403604e+09  Tuesday   378156754    27
# 4    481315991519895553  1.403604e+09  Tuesday  1332657980    27
# 5    481316289915269120  1.403604e+09  Tuesday  1191518725    27
# 6    481316442827403264  1.403604e+09  Tuesday    24752078    27
# 7    481316407645184000  1.403604e+09  Tuesday   246501877    27
# 8    481316359255896065  1.403604e+09  Tuesday   126849745    27
# 9    481316162413031424  1.403604e+09  Tuesday   434321517    27
# 10   481316374619631616  1.403604e+09  Tuesday   467880378    27
# 11   481316034679304192  1.403604e+09  Tuesday    70259182    27
# 12   481316072855838720  1.403604e+09  Tuesday   377650383    27
# 13   481316425739825152  1.403604e+09  Tuesday   805731500    27
# 14   481316645407715329  1.403604e+09  Tuesday   321569826    27
# 15   481316122067603456  1.403604e+09  Tuesday   361729073    27
# 16   481316379766050817  1.403604e+09  Tuesday    40233774    27
# 17   481316452343898112  1.403604e+09  Tuesday   180936318    27
# 18   481316169165860864  1.403604e+09  Tuesday    92920905    27
# 19   481316585529815041  1.403604e+09  Tuesday   321564282    27
# 20   481316708385587200  1.403604e+09  Tuesday   347042040    27
# 21   481316266096222208  1.403604e+09  Tuesday   434321517    27
# 22   481316226778415105  1.403604e+09  Tuesday  2243182261    27
# 23   481315993180852224  1.403604e+09  Tuesday   229680331    27
# 24   481316294084407296  1.403604e+09  Tuesday   901002504    27
# 25   481316113389998081  1.403604e+09  Tuesday   467880378    27
# 26   481316510862827520  1.403604e+09  Tuesday   201563391    27
# 27   481315832912281600  1.403604e+09  Tuesday  1191518725    27
# 28   481315991524098049  1.403604e+09  Tuesday   610645833    27
# 29   481316014060085248  1.403604e+09  Tuesday   254333246    27
# ..                  ...           ...      ...         ...   ...
# 71   481317306299977729  1.403604e+09  Tuesday   805731500    27
# 72   481316923515211776  1.403604e+09  Tuesday  2244688296    27
# 73   481317225614172161  1.403604e+09  Tuesday   304188561    27
# 74   481317153019138048  1.403604e+09  Tuesday   213035073    27
# 75   481316970143309824  1.403604e+09  Tuesday   104040214    27
# 76   481316827859939328  1.403604e+09  Tuesday   265404804    27
# 77   481317361446703105  1.403604e+09  Tuesday   613518994    27
# 78   481317621212512257  1.403604e+09  Tuesday   176951102    27
# 79   481316974765420544  1.403604e+09  Tuesday    70259182    27
# 80   481317482230067200  1.403604e+09  Tuesday   995838072    27
# 81   481316805072265216  1.403604e+09  Tuesday   104040214    27
# 82   481317440224100352  1.403604e+09  Tuesday  1455485894    27
# 83   481317423304675328  1.403604e+09  Tuesday  1066653360    27
# 84   481316817768427520  1.403604e+09  Tuesday  1191518725    27
# 85   481317435145203712  1.403604e+09  Tuesday    70259182    27
# 86   481317557316505601  1.403604e+09  Tuesday   434321517    27
# 87   481317594557730816  1.403604e+09  Tuesday   746450810    27
# 88   481316922051411968  1.403604e+09  Tuesday   361901935    27
# 89   481316995376246784  1.403604e+09  Tuesday   361729073    27
# 90   481317806202310656  1.403604e+09  Tuesday   518157147    27
# 91   481317807959703552  1.403604e+09  Tuesday  2243182261    27
# 92   481317823814189056  1.403604e+09  Tuesday   626942538    27
# 93   481316813934845954  1.403604e+09  Tuesday   758481487    27
# 94   481316807555698688  1.403604e+09  Tuesday   467880378    27
# 95   481316867856793600  1.403604e+09  Tuesday   325128255    27
# 96   481316864153243648  1.403604e+09  Tuesday   304188561    27
# 97   481317200708796417  1.403604e+09  Tuesday   150403488    27
# 98   481317344820486144  1.403604e+09  Tuesday   434321517    27
# 99   481317252957241344  1.403604e+09  Tuesday   483143141    27
# 100  481317053475741696  1.403604e+09  Tuesday    54890931    27
#
#                                          original text  \
# 0          I just made a fabulous grilled cheese omg 😍
# 1                   "What the frick" - @ash_morrison12
# 2                               @paigeschwarzroc comin
# 3    Glora-"Bryannnnnnn"\nMe-"Wuuuuuuuut"\nGloria-"...
# 4           I just want my big brother to come home ):
# 5                                             Naked? 😍
# 6    Lol workin (@ Brainerd Dispatch) http://t.co/a...
# 7    “@FunnyVines: Blarghablabla.. https://t.co/fxV...
# 8                   @CallMeKarizma Then we're all dead
# 9    @4orelllaaaa @LilMont_ nigga look like a Wendy...
# 10   @JackStamman @babylohnerr mooning people but t...
# 11                            I wish I had some steak.
# 12   Im a down to earth guy with intentions that’s ...
# 13   Furthest thing from perfect like everyone I kn...
# 14                           @laneyj42 @_Breezy_10 hey
# 15   "@althepaaal: Can't I just have a male friend ...
# 16                 @NeenoBrowne you guess pshhhhhh lol
# 17   happy birthday to my closest to a brother. lov...
# 18                                 @Lo_vanelsen thanks
# 19   I drank more than a pitcher of diet coke in an...
# 20         @ledonneforte @MrPrez35 @TheNoorFacee BETTT
# 21   @i_G0T_Clout 😂😂 oh yeah llmao that was dem goo...
# 22   I wish I had a cute boy who sent me cute littl...
# 23                               I never go on twitter
# 24   “@PraiseTheGanja: Imma kill this nigga 💯💯 http...
# 25   @JackStamman @babylohnerr what is that suppose...
# 26                 Getting mixed signals is the worst!
# 27                               How's it going baby 😏
# 28   My phone fucking acts up when it's on the char...
# 29                 @MyBlueWorld777 G'night sweets xo:)
# ..                                                 ...
# 71          Pull out a AK and pop you in ya funny bone
# 72              Well now im not gona be able to sleep😤
# 73   @mayaa_marieee damn I should of been messing w...
# 74                               Someone bring me food
# 75   @FuckM0untain it would be a lot of work. That'...
# 76   "@Derpey: when a skinny girl calls herself fat...
# 77   LLPD are camped out on county J, #WatchOutKidd...
# 78   My hair is about to naturally start dreading i...
# 79   My gramma has been heavy on my mind. The close...
# 80   I'm pretty sure that is Josh Bloje up there, #...
# 81   @Jarmuzekk @FuckM0untain id be a cool Asian bl...
# 82         When bae lookin fine http://t.co/EKkY6Gli5o
# 83                       So that's Armenian? #Sideways
# 84                               I miss @derekklejeski
# 85    I just really want steak and potatoes right now.
# 86                      @LilMont_ @4orelllaaaa lol bet
# 87    Damn it Jimmy Johns why can't you be open 24/7 😫
# 88   @Maynizzles dm me your # we going to kick it s...
# 89                 @althepaaal sorry I forgot to @ you
# 90                                   @aijaisamazing 🌚😏
# 91                     Kill your haters with kindness.
# 92                       Boondocks to end the night. 👌
# 93   Do you ever feel like too much has changed wit...
# 94   @JackStamman @babylohnerr still don't see what...
# 95   “@radkld: i like to hangout with people that m...
# 96                                 @mayaa_marieee smh.
# 97                           @SnakeFisher007 it shows.
# 98   @i_G0T_Clout boy I'm Finna flame yo dirty ear ...
# 99   I'm not very good at calculating shipping cost...
# 100                         At 01:01 AM – Temp: 66.9ºF
#
#                                        with_emoji_text  \
# 0          I just made a fabulous grilled cheese omg 😍
# 1                                   "What the frick" -
# 2                                                comin
# 3    Glora-"Bryannnnnnn" Me-"Wuuuuuuuut" Gloria-"Yo...
# 4           I just want my big brother to come home ):
# 5                                             Naked? 😍
# 6                     Lol workin (@ Brainerd Dispatch)
# 7                      “: Blarghablabla.. ” this is us
# 8                                  Then we're all dead
# 9    nigga look like a Wendy's chicken nugget yo fa...
# 10   mooning people but that's not like an insult t...
# 11                            I wish I had some steak.
# 12   Im a down to earth guy with intentions that’s ...
# 13   Furthest thing from perfect like everyone I kn...
# 14                                                 hey
# 15   ": Can't I just have a male friend who isn't a...
# 16                 @NeenoBrowne you guess pshhhhhh lol
# 17   happy birthday to my closest to a brother. lov...
# 18                                 @Lo_vanelsen thanks
# 19   I drank more than a pitcher of diet coke in an...
# 20                   @ledonneforte @TheNoorFacee BETTT
# 21          😂😂 oh yeah llmao that was dem good ol days
# 22   I wish I had a cute boy who sent me cute littl...
# 23                               I never go on twitter
# 24   “@PraiseTheGanja: Imma kill this nigga 💯💯 ”who...
# 25                       what is that suppose to mean?
# 26                 Getting mixed signals is the worst!
# 27                               How's it going baby 😏
# 28   My phone fucking acts up when it's on the char...
# 29                                 G'night sweets xo:)
# ..                                                 ...
# 71          Pull out a AK and pop you in ya funny bone
# 72              Well now im not gona be able to sleep😤
# 73              damn I should of been messing with you
# 74                               Someone bring me food
# 75   @FuckM0untain it would be a lot of work. That'...
# 76   ": when a skinny girl calls herself fat " This...
# 77              LLPD are camped out on county J, ✋👮🚨🚔🚓
# 78   My hair is about to naturally start dreading i...
# 79   My gramma has been heavy on my mind. The close...
# 80        I'm pretty sure that is Josh Bloje up there,
# 81   @FuckM0untain id be a cool Asian blonde right..??
# 82                                When bae lookin fine
# 83                                 So that's Armenian?
# 84                                              I miss
# 85    I just really want steak and potatoes right now.
# 86                                             lol bet
# 87    Damn it Jimmy Johns why can't you be open 24/7 😫
# 88            dm me your # we going to kick it soon 👌👌
# 89                             sorry I forgot to @ you
# 90                                   @aijaisamazing 🌚😏
# 91                     Kill your haters with kindness.
# 92                       Boondocks to end the night. 👌
# 93   Do you ever feel like too much has changed wit...
# 94    still don't see what you're trying to do here...
# 95   “@radkld: i like to hangout with people that m...
# 96                                                smh.
# 97                                           it shows.
# 98   boy I'm Finna flame yo dirty ear ass getcha it...
# 99   I'm not very good at calculating shipping cost...
# 100                         At 01:01 AM – Temp: 66.9ºF
#
#                                     without_emoji_text  \
# 0            I just made a fabulous grilled cheese omg
# 1                                   "What the frick" -
# 2                                                comin
# 3    Glora-"Bryannnnnnn" Me-"Wuuuuuuuut" Gloria-"Yo...
# 4           I just want my big brother to come home ):
# 5                                               Naked?
# 6                        Lol workin Brainerd Dispatch)
# 7                      “: Blarghablabla.. ” this is us
# 8                                  Then we're all dead
# 9    nigga look like a Wendy's chicken nugget yo fa...
# 10   mooning people but that's not like an insult t...
# 11                            I wish I had some steak.
# 12   Im a down to earth guy with intentions that’s ...
# 13    Furthest thing from perfect like everyone I know
# 14                                                 hey
# 15   ": Can't I just have a male friend who isn't a...
# 16                              you guess pshhhhhh lol
# 17   happy birthday to my closest to a brother. lov...
# 18                                              thanks
# 19   I drank more than a pitcher of diet coke in an...
# 20                                               BETTT
# 21             oh yeah llmao that was dem good ol days
# 22   I wish I had a cute boy who sent me cute littl...
# 23                               I never go on twitter
# 24     Imma kill this nigga ”who tf took the picture..
# 25                       what is that suppose to mean?
# 26                 Getting mixed signals is the worst!
# 27                                 How's it going baby
# 28   My phone fucking acts up when it's on the charger
# 29                                 G'night sweets xo:)
# ..                                                 ...
# 71          Pull out a AK and pop you in ya funny bone
# 72               Well now im not gona be able to sleep
# 73              damn I should of been messing with you
# 74                               Someone bring me food
# 75      it would be a lot of work. That's the problem.
# 76   ": when a skinny girl calls herself fat " This...
# 77                    LLPD are camped out on county J,
# 78   My hair is about to naturally start dreading i...
# 79   My gramma has been heavy on my mind. The close...
# 80        I'm pretty sure that is Josh Bloje up there,
# 81                 id be a cool Asian blonde right..??
# 82                                When bae lookin fine
# 83                                 So that's Armenian?
# 84                                              I miss
# 85    I just really want steak and potatoes right now.
# 86                                             lol bet
# 87      Damn it Jimmy Johns why can't you be open 24/7
# 88               dm me your # we going to kick it soon
# 89                               sorry I forgot to you
# 90
# 91                     Kill your haters with kindness.
# 92                         Boondocks to end the night.
# 93   Do you ever feel like too much has changed wit...
# 94    still don't see what you're trying to do here...
# 95   i like to hangout with people that make me for...
# 96                                                smh.
# 97                                           it shows.
# 98   boy I'm Finna flame yo dirty ear ass getcha it...
# 99   I'm not very good at calculating shipping cost...
# 100                         At 01:01 AM – Temp: 66.9ºF
#
#     in_reply_to_status_id_str  emoji         hashtag  \
# 0                        None      😍            None
# 1                        None                   None
# 2          481315964794179584                   None
# 3                        None                   None
# 4                        None                   None
# 5                        None      😍            None
# 6                        None                   None
# 7          476055025878183936                   None
# 8          481313267315245056                   None
# 9          481315646039281665                   None
# 10         481316227348836352                   None
# 11                       None                   None
# 12                       None                   None
# 13                       None      💯            None
# 14         481306721122414592                   None
# 15                       None                   None
# 16                       None                   None
# 17                       None                   None
# 18                       None                   None
# 19                       None                   None
# 20                       None                   None
# 21         481316082079133697     😂😂            None
# 22                       None                   None
# 23                       None                   None
# 24         481315863933362176     💯💯            None
# 25         481315898397978624                   None
# 26                       None                   None
# 27                       None      😏            None
# 28                       None      😒            None
# 29         481315904706609152                   None
# ..                        ...    ...             ...
# 71                       None                   None
# 72                       None      😤            None
# 73         481317032575508480                   None
# 74                       None                   None
# 75         481316881886752768                   None
# 76                       None                   None
# 77                       None  ✋👮🚨🚔🚓  WatchOutKiddos
# 78                       None                   None
# 79                       None                   None
# 80                       None                wheelin
# 81         481316410950295553                   None
# 82                       None                   None
# 83                       None               Sideways
# 84                       None                   None
# 85                       None                   None
# 86         481317473720213505                   None
# 87                       None      😫            None
# 88         481312709028225024     👌👌            None
# 89         481316801557438464                   None
# 90         481317700925276160     🌚😏            None
# 91                       None                   None
# 92                       None      👌            None
# 93                       None                   None
# 94         481316557142765568                   None
# 95         481166307404955648      👏            None
# 96         481316784524374016                   None
# 97         481315941817409536                   None
# 98         481316887632945152                   None
# 99                       None                   None
# 100                      None                   None
#
#                                       media(type, url)  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# 5                                                 None
# 6                                                 None
# 7                                                 None
# 8                                                 None
# 9                                                 None
# 10                                                None
# 11                                                None
# 12                                                None
# 13                                                None
# 14                                                None
# 15                                                None
# 16                                                None
# 17   (photo, https://pbs.twimg.com/media/Bq36w1uCcA...
# 18                                                None
# 19                                                None
# 20                                                None
# 21                                                None
# 22                                                None
# 23                                                None
# 24                                                None
# 25                                                None
# 26                                                None
# 27                                                None
# 28                                                None
# 29                                                None
# ..                                                 ...
# 71                                                None
# 72                                                None
# 73                                                None
# 74                                                None
# 75                                                None
# 76                                                None
# 77                                                None
# 78                                                None
# 79                                                None
# 80   (photo, https://pbs.twimg.com/media/Bq37spaCEA...
# 81                                                None
# 82   (photo, https://pbs.twimg.com/media/Bq37qO5CUA...
# 83                                                None
# 84                                                None
# 85                                                None
# 86                                                None
# 87                                                None
# 88                                                None
# 89                                                None
# 90                                                None
# 91                                                None
# 92                                                None
# 93                                                None
# 94                                                None
# 95                                                None
# 96                                                None
# 97                                                None
# 98                                                None
# 99                                                None
# 100                                               None
#
#                       user_mentions language
# 0                              None       en
# 1                        1102590956       en
# 2                        1871717250       en
# 3                              None       en
# 4                              None       en
# 5                              None       en
# 6                              None       en
# 7          [1396161031, 1234948957]       en
# 8                         461676724       en
# 9    [39367535, 729907855940157440]       en
# 10           [299418400, 444135301]       en
# 11                             None       en
# 12                             None       en
# 13                             None       en
# 14           [324183865, 497563855]      und
# 15                       1375322414       en
# 16                             None       en
# 17                         91880592       en
# 18                             None       en
# 19                             None       en
# 20                        427774568      und
# 21               900112582555598852       en
# 22                             None       en
# 23                             None       en
# 24                             None       en
# 25           [299418400, 444135301]       en
# 26                             None       en
# 27                             None       en
# 28                             None       en
# 29                        329893254       en
# ..                              ...      ...
# 71                             None       en
# 72                             None       en
# 73                        354132475       en
# 74                             None       en
# 75                             None       en
# 76           [598919816, 489044944]       en
# 77                             None       en
# 78                             None       en
# 79                             None       en
# 80                        194395336       en
# 81                        536963329       en
# 82                             None       en
# 83                             None       en
# 84                       1428991230       en
# 85                             None       en
# 86   [729907855940157440, 39367535]       en
# 87                             None       en
# 88                        576590935       en
# 89                       1375322414       en
# 90                             None      und
# 91                             None       en
# 92                             None       en
# 93                             None       en
# 94           [299418400, 444135301]       en
# 95                             None       en
# 96                        354132475      und
# 97                        185374806       en
# 98               900112582555598852       en
# 99                         19709040       en
# 100                            None       en
#
# [101 rows x 14 columns]
