# %%
import pandas as pd
import numpy as np
import re,os,json,pprint
import datetime
import emoji

# %%
def check_empty_and_unexist_files(file_path_list):
    good_file_path_list = []
    bad_file_path_list = []
    for file_path in file_path_list:
        if os.path.isfile(file_path) and (os.stat(file_path).st_size > 0):
            good_file_path_list.append(file_path)
        else:
            bad_file_path_list.append(file_path)
    if len(bad_file_path_list):
        print('These files are either empty or non-exist: ', bad_file_path_list)
    return good_file_path_list


def load_tweets_from_json(file_path):
    tweets = []
    for line in open(file_path,'r'):
        tweets.append(json.loads(line))
    return tweets


def get_value_by_two_steps(tweet,keys,targets,text):
    original_tweet_text = tweet['text']
    try:
        for key in keys:
            tweet = tweet[key]
    except KeyError:
        return None, text
    if len(tweet):
        if isinstance(targets,str):
            targets = (targets,)
        result = []
        for single_item in tweet:
            single_value = tuple((single_item[temp_target] for temp_target in targets))
            if len(single_value) == 1:
                single_value = single_value[0]
            result.append(single_value)
            #remove targets
            indices = single_item['indices']
            target_string = original_tweet_text[indices[0]:indices[1]]
            text = text.replace(target_string,'')
        if len(result) == 1:
            result = result[0]
        return result,text
    else:
        return None,text
    
def extract_emojis(txt):
    return ''.join(c for c in txt if c in emoji.UNICODE_EMOJI)

def extract_no_emojis_text(txt):
    return ''.join(c for c in txt if c not in emoji.UNICODE_EMOJI)

# %%
dirPath = '../data/state_id_2014-06_unzip/'
file_name_list = os.listdir(dirPath)
file_name_list = [file_name for file_name in file_name_list if re.findall('.+\.json$',file_name)]
file_path_list = [dirPath + file_name for file_name in file_name_list]

file_path_list = check_empty_and_unexist_files(file_path_list)

# %%
header = ['Tweet ID', 'timestamp', 'week', 'user_id', 'state', 'original text', 'with_emoji_text', 'with_emoji_text', 'emoji',
          'hashtag', 'media(type, url)', 'user_mentions', 'language']
final_result = []
for file_path in file_path_list:
    state_id = file_path.split('/')[-1].split('_')[1]
    tweets = load_tweets_from_json(file_path)
    i = 0
    for tweet in tweets:
        text = tweet['text']
        print('---------------------------------------------------------')
        print('original text:',text)
        print('emojies: ',extract_emojis(text))
        tweet_id = tweet['id_str']
        user_id = tweet['user']['id']
        language = tweet['lang']
        timestamp = datetime.datetime.strptime(tweet['created_at'],'%a %b %d %H:%M:%S +0000 %Y').timestamp()
        week = datetime.datetime.strptime(tweet['created_at'],'%a %b %d %H:%M:%S +0000 %Y').strftime('%A')
        hashtags,text = get_value_by_two_steps(tweet,['entities','hashtags'],'text',text)
        media,text = get_value_by_two_steps(tweet,['entities','media'],('type','media_url_https'),text)
        symbols,text = get_value_by_two_steps(tweet,['entities','symbols'],'text',text)
        urls,text = get_value_by_two_steps(tweet,['entities','urls'],'url',text)
        user_mentions, text = get_value_by_two_steps(tweet,['entities','user_mentions'],'id_str',text)
        text = re.sub( '\s+', ' ', text ).strip()
        print('\nhashtags: ',hashtags,'\nmedia: ',media,'\nsymbols: ',symbols,
              '\nurls: ',urls,'\nuser_mentions: ',user_mentions)
        print('\n with emoji',text)
        print('\n without emoji',extract_no_emojis_text(text))
        final_result.append([tweet_id, timestamp, week, user_id, state_id, tweet['text'], text, extract_no_emojis_text(text),extract_emojis(text),
                            hashtags, media, user_mentions, language])
        i = i +1
        if i > 100:
            break
        
    break
# Out:
# ---------------------------------------------------------
# original text: @Herc_Thurman you have xbox or ps3
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  393133331
#
#  with emoji you have xbox or ps3
#
#  without emoji you have xbox or ps3
# ---------------------------------------------------------
# original text: OMG. @Redneck_lovee just followed me! 🙌🙌
# emojies:  🙌🙌
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji OMG. @Redneck_lovee just followed me! 🙌🙌
#
#  without emoji OMG. @Redneck_lovee just followed me!
# ---------------------------------------------------------
# original text: The hardest choice in life is usually between what you want, and what you deserve.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji The hardest choice in life is usually between what you want, and what you deserve.
#
#  without emoji The hardest choice in life is usually between what you want, and what you deserve.
# ---------------------------------------------------------
# original text: @EmreeWitt ACTUALLY, there was soap...S.E. girl...
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  423639698
#
#  with emoji ACTUALLY, there was soap...S.E. girl...
#
#  without emoji ACTUALLY, there was soap...S.E. girl...
# ---------------------------------------------------------
# original text: It's 2am my butt bout to be kO'd. He better hurry up.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji It's 2am my butt bout to be kO'd. He better hurry up.
#
#  without emoji It's 2am my butt bout to be kO'd. He better hurry up.
# ---------------------------------------------------------
# original text: "@SnapchatProbbz: I LOVE NOT WEARING MAKEUP BC I CAN JUST RUB MY EYES AND NOTHING HAPPENS"
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  971277218
#
#  with emoji ": I LOVE NOT WEARING MAKEUP BC I CAN JUST RUB MY EYES AND NOTHING HAPPENS"
#
#  without emoji ": I LOVE NOT WEARING MAKEUP BC I CAN JUST RUB MY EYES AND NOTHING HAPPENS"
# ---------------------------------------------------------
# original text: I'm too obsessed with shows about Big Foot.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji I'm too obsessed with shows about Big Foot.
#
#  without emoji I'm too obsessed with shows about Big Foot.
# ---------------------------------------------------------
# original text: Got me listening to this like http://t.co/e4cKDwveWR via @youtube
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  http://t.co/e4cKDwveWR
# user_mentions:  10228272
#
#  with emoji Got me listening to this like via
#
#  without emoji Got me listening to this like via
# ---------------------------------------------------------
# original text: "@ThSpoiledBitch: Truth is I don't think you'll ever change"
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  481792176
#
#  with emoji ": Truth is I don't think you'll ever change"
#
#  without emoji ": Truth is I don't think you'll ever change"
# ---------------------------------------------------------
# original text: Who do you love ?
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Who do you love ?
#
#  without emoji Who do you love ?
# ---------------------------------------------------------
# original text: Really going to cut my hair off 💇
# emojies:  💇
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Really going to cut my hair off 💇
#
#  without emoji Really going to cut my hair off
# ---------------------------------------------------------
# original text: Yeah, true http://t.co/d7fjiCXcYe
# emojies:
#
# hashtags:  None
# media:  ('photo', 'https://pbs.twimg.com/media/BpLxPgmCcAETgOR.jpg')
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Yeah, true
#
#  without emoji Yeah, true
# ---------------------------------------------------------
# original text: what did you do to me.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji what did you do to me.
#
#  without emoji what did you do to me.
# ---------------------------------------------------------
# original text: There are 18 dorms either in use/currently being built on south campus alone at UK.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji There are 18 dorms either in use/currently being built on south campus alone at UK.
#
#  without emoji There are 18 dorms either in use/currently being built on south campus alone at UK.
# ---------------------------------------------------------
# original text: Goodnight handsomes and beauties!♥♡
# emojies:  ♥
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Can't Fall Asleep
#
#  without emoji Can't Fall Asleep
# ---------------------------------------------------------
# original text: @EmreeWitt smells like you need to..
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  423639698
#
#  with emoji smells like you need to..
#
#  without emoji smells like you need to..
# ---------------------------------------------------------
# original text: Temptation was a really good movie! #GottaLoveTylerPerry
# emojies:
#
# hashtags:  GottaLoveTylerPerry
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Temptation was a really good movie!
#
#  without emoji Temptation was a really good movie!
# ---------------------------------------------------------
# original text: Dog Phoenix butt was close to my face. Dude just lit the room up, I can't breathe and I don't want to taste the fart. #beyondfoul
# emojies:
#
# hashtags:  beyondfoul
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Dog Phoenix butt was close to my face. Dude just lit the room up, I can't breathe and I don't want to taste the fart.
#
#  without emoji Dog Phoenix butt was close to my face. Dude just lit the room up, I can't breathe and I don't want to taste the fart.
# ---------------------------------------------------------
# original text: Wind 1.0 mph W. Barometer 30.006 in, Rising slowly. Temperature 70.7 °F. Rain today 0.00 in. Humidity 92%
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Wind 1.0 mph W. Barometer 30.006 in, Rising slowly. Temperature 70.7 °F. Rain today 0.00 in. Humidity 92%
#
#  without emoji Wind 1.0 mph W. Barometer 30.006 in, Rising slowly. Temperature 70.7 °F. Rain today 0.00 in. Humidity 92%
# ---------------------------------------------------------
# original text: "@AwesomityFun: I’m not a morning person I’m not even an afternoon person I pretty much start functioning at about 7pm"
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  981057535
#
#  with emoji ": I’m not a morning person I’m not even an afternoon person I pretty much start functioning at about 7pm"
#
#  without emoji ": I’m not a morning person I’m not even an afternoon person I pretty much start functioning at about 7pm"
# ---------------------------------------------------------
# original text: @_PURPleBomb who
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  388380241
#
#  with emoji who
#
#  without emoji who
# ---------------------------------------------------------
# original text: When you think all is gone, there is always that little bit of hope that will help you stand back up!
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji When you think all is gone, there is always that little bit of hope that will help you stand back up!
#
#  without emoji When you think all is gone, there is always that little bit of hope that will help you stand back up!
# ---------------------------------------------------------
# original text: I wish you could press a button and just forget the bad memories...
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji I wish you could press a button and just forget the bad memories...
#
#  without emoji I wish you could press a button and just forget the bad memories...
# ---------------------------------------------------------
# original text: @_PURPleBomb bitch I already know
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  388380241
#
#  with emoji bitch I already know
#
#  without emoji bitch I already know
# ---------------------------------------------------------
# original text: Couldn't have said it better myself. http://t.co/FThuElUz1n
# emojies:
#
# hashtags:  None
# media:  ('photo', 'https://pbs.twimg.com/media/BpLxWu6CEAAK6L4.jpg')
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Couldn't have said it better myself.
#
#  without emoji Couldn't have said it better myself.
# ---------------------------------------------------------
# original text: I cant fuckin shleppp
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji I cant fuckin shleppp
#
#  without emoji I cant fuckin shleppp
# ---------------------------------------------------------
# original text: Whatever
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Whatever
#
#  without emoji Whatever
# ---------------------------------------------------------
# original text: #Marine held in Mexico Crab Orchard, Ky. Temp is: 70.3°F Wind Chill: 70.3°F Winds are out of the ESE at 0.0 mph Pressure: 29.54 in and is St
# emojies:
#
# hashtags:  Marine
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji held in Mexico Crab Orchard, Ky. Temp is: 70.3°F Wind Chill: 70.3°F Winds are out of the ESE at 0.0 mph Pressure: 29.54 in and is St
#
#  without emoji held in Mexico Crab Orchard, Ky. Temp is: 70.3°F Wind Chill: 70.3°F Winds are out of the ESE at 0.0 mph Pressure: 29.54 in and is St
# ---------------------------------------------------------
# original text: God will never leave you..
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji God will never leave you..
#
#  without emoji God will never leave you..
# ---------------------------------------------------------
# original text: Hunter is fulfilling my mind with astounding facts right now
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Hunter is fulfilling my mind with astounding facts right now
#
#  without emoji Hunter is fulfilling my mind with astounding facts right now
# ---------------------------------------------------------
# original text: @MeganTaylor_MTA who r u?
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  284197176
#
#  with emoji who r u?
#
#  without emoji who r u?
# ---------------------------------------------------------
# original text: Hahaha no drug testing at model . Whatta shame
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Hahaha no drug testing at model . Whatta shame
#
#  without emoji Hahaha no drug testing at model . Whatta shame
# ---------------------------------------------------------
# original text: @EmreeWitt are you smelling yourself cause i took a bath?
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  423639698
#
#  with emoji are you smelling yourself cause i took a bath?
#
#  without emoji are you smelling yourself cause i took a bath?
# ---------------------------------------------------------
# original text: "@StevStiffler: Some songs just wake up my inner stripper." So true, lol.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  133682123
#
#  with emoji ": Some songs just wake up my inner stripper." So true, lol.
#
#  without emoji ": Some songs just wake up my inner stripper." So true, lol.
# ---------------------------------------------------------
# original text: Not only does #TFIOS premiere Friday but also season 2 Orange is the New Black!!!!!!!!!!!!!!!!!!
# emojies:
#
# hashtags:  TFIOS
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Not only does premiere Friday but also season 2 Orange is the New Black!!!!!!!!!!!!!!!!!!
#
#  without emoji Not only does premiere Friday but also season 2 Orange is the New Black!!!!!!!!!!!!!!!!!!
# ---------------------------------------------------------
# original text: Watching full house with @etill35! 💁
# emojies:  💁
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Watching full house with @etill35! 💁
#
#  without emoji Watching full house with @etill35!
# ---------------------------------------------------------
# original text: My head is bustin! 😩
# emojies:  😩
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji My head is bustin! 😩
#
#  without emoji My head is bustin!
# ---------------------------------------------------------
# original text: @Chrissaaaaaaaa 😂😂😂
# emojies:  😂😂😂
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  270494575
#
#  with emoji 😂😂😂
#
#  without emoji
# ---------------------------------------------------------
# original text: I literally say fuck so often I’m starting to think we need a new word that’s more offensive than fuck.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji I literally say fuck so often I’m starting to think we need a new word that’s more offensive than fuck.
#
#  without emoji I literally say fuck so often I’m starting to think we need a new word that’s more offensive than fuck.
# ---------------------------------------------------------
# original text: Another boring night
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Another boring night
#
#  without emoji Another boring night
# ---------------------------------------------------------
# original text: I cant.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji I cant.
#
#  without emoji I cant.
# ---------------------------------------------------------
# original text: he don't wife em, he one nights em
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji he don't wife em, he one nights em
#
#  without emoji he don't wife em, he one nights em
# ---------------------------------------------------------
# original text: forcing myself to go to sleep now 😁
# emojies:  😁
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji forcing myself to go to sleep now 😁
#
#  without emoji forcing myself to go to sleep now
# ---------------------------------------------------------
# original text: *builds 10 new massive buildings*
# "GUYS WE ARE RUNNING OUT OF MONEY! We are raising tuition."
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji *builds 10 new massive buildings* "GUYS WE ARE RUNNING OUT OF MONEY! We are raising tuition."
#
#  without emoji *builds 10 new massive buildings* "GUYS WE ARE RUNNING OUT OF MONEY! We are raising tuition."
# ---------------------------------------------------------
# original text: #IfWeDate don't worry about me cheating. I'm with you for a reason. I want you and only you. And when I'm not happy, I'll let you know.
# emojies:
#
# hashtags:  IfWeDate
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji don't worry about me cheating. I'm with you for a reason. I want you and only you. And when I'm not happy, I'll let you know.
#
#  without emoji don't worry about me cheating. I'm with you for a reason. I want you and only you. And when I'm not happy, I'll let you know.
# ---------------------------------------------------------
# original text: Sorry🙊
# emojies:  🙊
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Sorry🙊
#
#  without emoji Sorry
# ---------------------------------------------------------
# original text: @BOMBBERRY_ 😳😳😳
# emojies:  😳😳😳
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  243616995
#
#  with emoji 😳😳😳
#
#  without emoji
# ---------------------------------------------------------
# original text: #RuinARealityShow Finding Bigfoot, naked looking in my fridge
# emojies:
#
# hashtags:  RuinARealityShow
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Finding Bigfoot, naked looking in my fridge
#
#  without emoji Finding Bigfoot, naked looking in my fridge
# ---------------------------------------------------------
# original text: Only people you care about can upset you..
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Only people you care about can upset you..
#
#  without emoji Only people you care about can upset you..
# ---------------------------------------------------------
# original text: I need a new bow. 😂 🎯
# emojies:  😂🎯
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji I need a new bow. 😂 🎯
#
#  without emoji I need a new bow.
# ---------------------------------------------------------
# original text: #RuinARealityShow Topless Chef
# emojies:
#
# hashtags:  RuinARealityShow
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Topless Chef
#
#  without emoji Topless Chef
# ---------------------------------------------------------
# original text: hope I can go to sleep before 6 this time😞
# emojies:  😞
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji hope I can go to sleep before 6 this time😞
#
#  without emoji hope I can go to sleep before 6 this time
# ---------------------------------------------------------
# original text: @_PURPleBomb bitch I know the feeling
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  388380241
#
#  with emoji bitch I know the feeling
#
#  without emoji bitch I know the feeling
# ---------------------------------------------------------
# original text: Nothing good ever happens after 2 AM.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Nothing good ever happens after 2 AM.
#
#  without emoji Nothing good ever happens after 2 AM.
# ---------------------------------------------------------
# original text: I use to really want #oomf
# emojies:
#
# hashtags:  oomf
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji I use to really want
#
#  without emoji I use to really want
# ---------------------------------------------------------
# original text: Pandora is playing a lot if good songs tonight ☺️
# emojies:  ☺
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Pandora is playing a lot if good songs tonight ☺️
#
#  without emoji Pandora is playing a lot if good songs tonight ️
# ---------------------------------------------------------
# original text: I know u like no other but I will never be able to understand u and what goes on in that head of yours💯
# emojies:  💯
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji I know u like no other but I will never be able to understand u and what goes on in that head of yours💯
#
#  without emoji I know u like no other but I will never be able to understand u and what goes on in that head of yours
# ---------------------------------------------------------
# original text: If you're going to be a player know how to play the game. 😘👌
# emojies:  😘👌
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji If you're going to be a player know how to play the game. 😘👌
#
#  without emoji If you're going to be a player know how to play the game.
# ---------------------------------------------------------
# original text: @jungfeves is this me ?
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji @jungfeves is this me ?
#
#  without emoji @jungfeves is this me ?
# ---------------------------------------------------------
# original text: Just kidding DRUGZ R BAD HHAAHAH
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Just kidding DRUGZ R BAD HHAAHAH
#
#  without emoji Just kidding DRUGZ R BAD HHAAHAH
# ---------------------------------------------------------
# original text: Got me listening to this country shit... Tf?
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Got me listening to this country shit... Tf?
#
#  without emoji Got me listening to this country shit... Tf?
# ---------------------------------------------------------
# original text: “@Twerkerella: I need at least 22 hours of sleep” @MZik sounds about right
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  ['913527120', '36208928']
#
#  with emoji “: I need at least 22 hours of sleep” sounds about right
#
#  without emoji “: I need at least 22 hours of sleep” sounds about right
# ---------------------------------------------------------
# original text: Can't sleep 😖
# emojies:  😖
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Can't sleep 😖
#
#  without emoji Can't sleep
# ---------------------------------------------------------
# original text: Jesus took the nails I deserved and I will never let anyone convince me of the truth that I believe. His love is amazing. Jesus is King.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Jesus took the nails I deserved and I will never let anyone convince me of the truth that I believe. His love is amazing. Jesus is King.
#
#  without emoji Jesus took the nails I deserved and I will never let anyone convince me of the truth that I believe. His love is amazing. Jesus is King.
# ---------------------------------------------------------
# original text: this bed tho &gt; 😍
# emojies:  😍
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji this bed tho &gt; 😍
#
#  without emoji this bed tho &gt;
# ---------------------------------------------------------
# original text: Wide awake with no one to talk too😒 #great
# emojies:  😒
#
# hashtags:  great
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Wide awake with no one to talk too😒
#
#  without emoji Wide awake with no one to talk too
# ---------------------------------------------------------
# original text: Hate this feeling
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Hate this feeling
#
#  without emoji Hate this feeling
# ---------------------------------------------------------
# original text: @idrinkPINK_ 😂😂😂😂😂😂
# emojies:  😂😂😂😂😂😂
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  334695679
#
#  with emoji 😂😂😂😂😂😂
#
#  without emoji
# ---------------------------------------------------------
# original text: On that note good nite everyone👌
# emojies:  👌
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji On that note good nite everyone👌
#
#  without emoji On that note good nite everyone
# ---------------------------------------------------------
# original text: bæ
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji bæ
#
#  without emoji bæ
# ---------------------------------------------------------
# original text: @HunterWilson45 I appreciate the additional knowledge
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  984067675
#
#  with emoji I appreciate the additional knowledge
#
#  without emoji I appreciate the additional knowledge
# ---------------------------------------------------------
# original text: @EmreeWitt LOL ok
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  423639698
#
#  with emoji LOL ok
#
#  without emoji LOL ok
# ---------------------------------------------------------
# original text: “@OhThatsKev: "@LegitTheDj: If I text u and u don't text back I'm deleting your number" real nigga shit tho” on my life
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  ['50685688', '41849244']
#
#  with emoji “: ": If I text u and u don't text back I'm deleting your number" real nigga shit tho” on my life
#
#  without emoji “: ": If I text u and u don't text back I'm deleting your number" real nigga shit tho” on my life
# ---------------------------------------------------------
# original text: Hippos attract mates by urinating and defecating
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji Hippos attract mates by urinating and defecating
#
#  without emoji Hippos attract mates by urinating and defecating
# ---------------------------------------------------------
# original text: @AskMyselfWhy I back this 100%.
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  819311696804249601
#
#  with emoji I back this 100%.
#
#  without emoji I back this 100%.
# ---------------------------------------------------------
# original text: If I text u and u don't text back I'm deleting your number
# emojies:
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:  None
#
#  with emoji If I text u and u don't text back I'm deleting your number
#
#  without emoji If I text u and u don't text back I'm deleting your number
# ---------------------------------------------------------
# original text: “@_PURPleBomb: “@_4EverDOPE_: @_PURPleBomb who” KP 😂😂✊💁”😂😂 I had a feeling u was talking about him
# emojies:  😂😂✊💁😂😂
#
# hashtags:  None
# media:  None
# symbols:  None
# urls:  None
# user_mentions:
# 78                                 @idrinkPINK_ 😂😂😂😂😂😂
# 79                    On that note good nite everyone👌
# 80                                                  bæ
# 81   @HunterWilson45 I appreciate the additional kn...
# 82                                   @EmreeWitt LOL ok
# 83   “@OhThatsKev: "@LegitTheDj: If I text u and u ...
# 84    Hippos attract mates by urinating and defecating
# 85                     @AskMyselfWhy I back this 100%.
# 86   If I text u and u don't text back I'm deleting...
# 87   “@_PURPleBomb: “@_4EverDOPE_: @_PURPleBomb who...
# 88   “@LoveCuteText: girls on Instagram vs girls in...
# 89   @MeganTaylor_MTA go smoke ya dope and chill wi...
# 90   I will never feel safe in this house again aft...
# 91   #Marine held in Mexico Crab Orchard, Ky. Temp ...
# 92       #RuinARealityShow My Cat from a shady breeder
# 93         Alexander Theodore Shulgin. Read about him.
# 94                                  320 @alexispaige49
# 95   @RavenEisenbeis they were like "here's my chan...
# 96                                                   😷
# 97   @RavenEisenbeis it was like seriously embarras...
# 98   “@dreamingSTAR_: I'm Feeling So Sad Right Now ...
# 99                  #RuinARealityShow South Beach Toes
# 100                                      kirko bangz 🍬
#
#                                        with_emoji_text  \
# 0                                 you have xbox or ps3
# 1             OMG. @Redneck_lovee just followed me! 🙌🙌
# 2    The hardest choice in life is usually between ...
# 3              ACTUALLY, there was soap...S.E. girl...
# 4    It's 2am my butt bout to be kO'd. He better hu...
# 5    ": I LOVE NOT WEARING MAKEUP BC I CAN JUST RUB...
# 6          I'm too obsessed with shows about Big Foot.
# 7                    Got me listening to this like via
# 8        ": Truth is I don't think you'll ever change"
# 9                                    Who do you love ?
# 10                   Really going to cut my hair off 💇
# 11                                          Yeah, true
# 12                              what did you do to me.
# 13   There are 18 dorms either in use/currently bei...
# 14                 Goodnight handsomes and beauties!♥♡
# 15   held in Mexico Crab Orchard, Ky. Temp is: 70.2...
# 16   When life pushes you down, it's testing you to...
# 17   BEST LOOKING MAN I EVER SEEN, EMAGINE HIM IN N...
# 18                                       😧😧 bitch who?
# 19   yup but I didn't say anything about anything ....
# 20   I've not been home an hour and I already miss ...
# 21                                         far go away
# 22                            Another sleepless night.
# 23   I love Cher'ron bruh. That's my a1 in Tennesse...
# 24   Funny how the good ones go, too soon but the g...
# 25                                   Can't Fall Asleep
# 26                           smells like you need to..
# 27                 Temptation was a really good movie!
# 28   Dog Phoenix butt was close to my face. Dude ju...
# 29   Wind 1.0 mph W. Barometer 30.006 in, Rising sl...
# ..                                                 ...
# 71        Got me listening to this country shit... Tf?
# 72   “: I need at least 22 hours of sleep” sounds a...
# 73                                       Can't sleep 😖
# 74   Jesus took the nails I deserved and I will nev...
# 75                                 this bed tho &gt; 😍
# 76                 Wide awake with no one to talk too😒
# 77                                   Hate this feeling
# 78                                              😂😂😂😂😂😂
# 79                    On that note good nite everyone👌
# 80                                                  bæ
# 81               I appreciate the additional knowledge
# 82                                              LOL ok
# 83   “: ": If I text u and u don't text back I'm de...
# 84    Hippos attract mates by urinating and defecating
# 85                                   I back this 100%.
# 86   If I text u and u don't text back I'm deleting...
